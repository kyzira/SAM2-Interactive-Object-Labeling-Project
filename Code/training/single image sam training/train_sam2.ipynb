# %% [markdown]
# # Training of SAM2 with conversion of Dataset
# [Source for Training part](https://github.com/sagieppel/fine-tune-train_segment_anything_2_in_60_lines_of_code)

# %%
import numpy as np
import torch
import cv2
import os
import json
from PIL import Image, ImageDraw
import shutil
from sam2.build_sam import build_sam2
from sam2.sam2_image_predictor import SAM2ImagePredictor

# %% [markdown]
# Set the paths of the labeled data and set the formatted dataset

# %%
labeled_dataset_path = r"C:\Users\K3000\Desktop\conversion test\old format"
formatted_dataset_path = r"C:\Users\K3000\Desktop\conversion test\new format"

# %% [markdown]
# ## Conversion
# This step converts the labeled dataset into the correct data format, if already formatted dataset exists, this step can be skipped.

# %%
def generate_masks(dataset_path, output_path):
    # Create new directory structure
    images_output_path = os.path.join(output_path, "Images")
    masks_output_path = os.path.join(output_path, "Masks")
    os.makedirs(images_output_path, exist_ok=True)
    os.makedirs(masks_output_path, exist_ok=True)

    # Traverse the directory structure
    for video_folder in os.listdir(dataset_path):
        video_path = os.path.join(dataset_path, video_folder)
        if not os.path.isdir(video_path):
            continue

        # Locate the JSON file
        json_file = [f for f in os.listdir(video_path) if f.endswith('.json')]
        if len(json_file) != 1:
            print(f"JSON file not found or multiple JSONs in {video_path}")
            continue
        json_path = os.path.join(video_path, json_file[0])

        # Parse the JSON
        with open(json_path, 'r') as f:
            annotations = json.load(f)

        # Locate the source images directory
        images_path = os.path.join(video_path, "source images")
        if not os.path.exists(images_path):
            print(f"Source images directory not found in {video_path}")
            continue

        # Process images and masks
        for image_file in os.listdir(images_path):
            if not image_file.endswith('.jpg'):
                continue

            # Image number based on filename
            image_number = str(int(os.path.splitext(image_file)[0]))

            # Get corresponding annotations
            if image_number not in annotations:
                print(f"No annotations for {image_file}")
                continue

            # Read the image dimensions
            image_path = os.path.join(images_path, image_file)
            with Image.open(image_path) as img:
                width, height = img.size

            # Copy the image to the new directory
            image_output_path = os.path.join(images_output_path, f"{video_folder}_{image_file}")
            shutil.copy(image_path, image_output_path)

            # Create a blank mask
            mask = Image.new("L", (width, height), 0)

            # Draw polygons onto the mask
            draw = ImageDraw.Draw(mask)
            observations = annotations[image_number]["Observations"]

            for category_idx, observation in enumerate(observations.values(), start=1):
                for mask_polygon in observation.get("Mask Polygon", []):
                    # Extract points and draw each polygon
                    points = [(int(point[0]), int(point[1])) for point in mask_polygon]
                    if len(points) > 2:  # Ensure it's a valid polygon
                        draw.polygon(points, fill=category_idx)

            # Save the mask
            mask_output_path = os.path.join(masks_output_path, f"{video_folder}_{int(image_number):05d}.png")
            mask.save(mask_output_path)
            print(f"Saved image: {image_output_path}, mask: {mask_output_path}")



generate_masks(labeled_dataset_path, formatted_dataset_path)
# Out:
# Saved image: C:\Users\K3000\Desktop\conversion test\new format\Images\01850100.MPG_02550.jpg, mask: C:\Users\K3000\Desktop\conversion test\new format\Masks\01850100.MPG_02550.png
# Saved image: C:\Users\K3000\Desktop\conversion test\new format\Images\01850100.MPG_02575.jpg, mask: C:\Users\K3000\Desktop\conversion test\new format\Masks\01850100.MPG_02575.png
# Saved image: C:\Users\K3000\Desktop\conversion test\new format\Images\01850100.MPG_02600.jpg, mask: C:\Users\K3000\Desktop\conversion test\new format\Masks\01850100.MPG_02600.png
# Saved image: C:\Users\K3000\Desktop\conversion test\new format\Images\01850100.MPG_02625.jpg, mask: C:\Users\K3000\Desktop\conversion test\new format\Masks\01850100.MPG_02625.png
# Saved image: C:\Users\K3000\Desktop\conversion test\new format\Images\01850100.MPG_02650.jpg, mask: C:\Users\K3000\Desktop\conversion test\new format\Masks\01850100.MPG_02650.png
# Saved image: C:\Users\K3000\Desktop\conversion test\new format\Images\01850100.MPG_02675.jpg, mask: C:\Users\K3000\Desktop\conversion test\new format\Masks\01850100.MPG_02675.png
# Saved image: C:\Users\K3000\Desktop\conversion test\new format\Images\01850100.MPG_02700.jpg, mask: C:\Users\K3000\Desktop\conversion test\new format\Masks\01850100.MPG_02700.png
# Saved image: C:\Users\K3000\Desktop\conversion test\new format\Images\01850100.MPG_02725.jpg, mask: C:\Users\K3000\Desktop\conversion test\new format\Masks\01850100.MPG_02725.png
# Saved image: C:\Users\K3000\Desktop\conversion test\new format\Images\01850100.MPG_02750.jpg, mask: C:\Users\K3000\Desktop\conversion test\new format\Masks\01850100.MPG_02750.png
# Saved image: C:\Users\K3000\Desktop\conversion test\new format\Images\01850100.MPG_02775.jpg, mask: C:\Users\K3000\Desktop\conversion test\new format\Masks\01850100.MPG_02775.png
# Saved image: C:\Users\K3000\Desktop\conversion test\new format\Images\01850100.MPG_02800.jpg, mask: C:\Users\K3000\Desktop\conversion test\new format\Masks\01850100.MPG_02800.png
# Saved image: C:\Users\K3000\Desktop\conversion test\new format\Images\01850100.MPG_02825.jpg, mask: C:\Users\K3000\Desktop\conversion test\new format\Masks\01850100.MPG_02825.png
# Saved image: C:\Users\K3000\Desktop\conversion test\new format\Images\01850100.MPG_02850.jpg, mask: C:\Users\K3000\Desktop\conversion test\new format\Masks\01850100.MPG_02850.png
# Saved image: C:\Users\K3000\Desktop\conversion test\new format\Images\01850100.MPG_02950.jpg, mask: C:\Users\K3000\Desktop\conversion test\new format\Masks\01850100.MPG_02950.png
# Saved image: C:\Users\K3000\Desktop\conversion test\new format\Images\01850100.MPG_02975.jpg, mask: C:\Users\K3000\Desktop\conversion test\new format\Masks\01850100.MPG_02975.png
# Saved image: C:\Users\K3000\Desktop\conversion test\new format\Images\01850100.MPG_03000.jpg, mask: C:\Users\K3000\Desktop\conversion test\new format\Masks\01850100.MPG_03000.png
# Saved image: C:\Users\K3000\Desktop\conversion test\new format\Images\01850100.MPG_03025.jpg, mask: C:\Users\K3000\Desktop\conversion test\new format\Masks\01850100.MPG_03025.png
# Saved image: C:\Users\K3000\Desktop\conversion test\new format\Images\01850100.MPG_03050.jpg, mask: C:\Users\K3000\Desktop\conversion test\new format\Masks\01850100.MPG_03050.png
# Saved image: C:\Users\K3000\Desktop\conversion test\new format\Images\01850100.MPG_03075.jpg, mask: C:\Users\K3000\Desktop\conversion test\new format\Masks\01850100.MPG_03075.png
# Saved image: C:\Users\K3000\Desktop\conversion test\new format\Images\01850100.MPG_03100.jpg, mask: C:\Users\K3000\Desktop\conversion test\new format\Masks\01850100.MPG_03100.png
# Saved image: C:\Users\K3000\Desktop\conversion test\new format\Images\01850100.MPG_03125.jpg, mask: C:\Users\K3000\Desktop\conversion test\new format\Masks\01850100.MPG_03125.png
# Saved image: C:\Users\K3000\Desktop\conversion test\new format\Images\01850100.MPG_03175.jpg, mask: C:\Users\K3000\Desktop\conversion test\new format\Masks\01850100.MPG_03175.png
# Saved image: C:\Users\K3000\Desktop\conversion test\new format\Images\01850100.MPG_03200.jpg, mask: C:\Users\K3000\Desktop\conversion test\new format\Masks\01850100.MPG_03200.png
# Saved image: C:\Users\K3000\Desktop\conversion test\new format\Images\01850151.MPG_04500.jpg, mask: C:\Users\K3000\Desktop\conversion test\new format\Masks\01850151.MPG_04500.png
# Saved image: C:\Users\K3000\Desktop\conversion test\new format\Images\01850151.MPG_04525.jpg, mask: C:\Users\K3000\Desktop\conversion test\new format\Masks\01850151.MPG_04525.png
# Saved image: C:\Users\K3000\Desktop\conversion test\new format\Images\01850151.MPG_04725.jpg, mask: C:\Users\K3000\Desktop\conversion test\new format\Masks\01850151.MPG_04725.png
# Saved image: C:\Users\K3000\Desktop\conversion test\new format\Images\01850151.MPG_04750.jpg, mask: C:\Users\K3000\Desktop\conversion test\new format\Masks\01850151.MPG_04750.png
# Saved image: C:\Users\K3000\Desktop\conversion test\new format\Images\01850151.MPG_04775.jpg, mask: C:\Users\K3000\Desktop\conversion test\new format\Masks\01850151.MPG_04775.png
# No annotations for 04800.jpg
# Saved image: C:\Users\K3000\Desktop\conversion test\new format\Images\01850151.MPG_04825.jpg, mask: C:\Users\K3000\Desktop\conversion test\new format\Masks\01850151.MPG_04825.png
# Saved image: C:\Users\K3000\Desktop\conversion test\new format\Images\01850151.MPG_04850.jpg, mask: C:\Users\K3000\Desktop\conversion test\new format\Masks\01850151.MPG_04850.png
# Saved image: C:\Users\K3000\Desktop\conversion test\new format\Images\01850151.MPG_04875.jpg, mask: C:\Users\K3000\Desktop\conversion test\new format\Masks\01850151.MPG_04875.png
# Saved image: C:\Users\K3000\Desktop\conversion test\new format\Images\01850151.MPG_04900.jpg, mask: C:\Users\K3000\Desktop\conversion test\new format\Masks\01850151.MPG_04900.png
# Saved image: C:\Users\K3000\Desktop\conversion test\new format\Images\01850151.MPG_04925.jpg, mask: C:\Users\K3000\Desktop\conversion test\new format\Masks\01850151.MPG_04925.png
# Saved image: C:\Users\K3000\Desktop\conversion test\new format\Images\01850151.MPG_05025.jpg, mask: C:\Users\K3000\Desktop\conversion test\new format\Masks\01850151.MPG_05025.png
# Saved image: C:\Users\K3000\Desktop\conversion test\new format\Images\01850151.MPG_05050.jpg, mask: C:\Users\K3000\Desktop\conversion test\new format\Masks\01850151.MPG_05050.png
# Saved image: C:\Users\K3000\Desktop\conversion test\new format\Images\01850151.MPG_05075.jpg, mask: C:\Users\K3000\Desktop\conversion test\new format\Masks\01850151.MPG_05075.png
# No annotations for 05100.jpg
# No annotations for 05125.jpg
# No annotations for 05150.jpg
# Saved image: C:\Users\K3000\Desktop\conversion test\new format\Images\01850151.MPG_05175.jpg, mask: C:\Users\K3000\Desktop\conversion test\new format\Masks\01850151.MPG_05175.png
# Saved image: C:\Users\K3000\Desktop\conversion test\new format\Images\01850151.MPG_05200.jpg, mask: C:\Users\K3000\Desktop\conversion test\new format\Masks\01850151.MPG_05200.png
# Saved image: C:\Users\K3000\Desktop\conversion test\new format\Images\01850151.MPG_05225.jpg, mask: C:\Users\K3000\Desktop\conversion test\new format\Masks\01850151.MPG_05225.png
# Saved image: C:\Users\K3000\Desktop\conversion test\new format\Images\01850151.MPG_05250.jpg, mask: C:\Users\K3000\Desktop\conversion test\new format\Masks\01850151.MPG_05250.png
# Saved image: C:\Users\K3000\Desktop\conversion test\new format\Images\01850151.MPG_05300.jpg, mask: C:\Users\K3000\Desktop\conversion test\new format\Masks\01850151.MPG_05300.png
# Saved image: C:\Users\K3000\Desktop\conversion test\new format\Images\01850151.MPG_06275.jpg, mask: C:\Users\K3000\Desktop\conversion test\new format\Masks\01850151.MPG_06275.png
# No annotations for 06300.jpg
# No annotations for 06325.jpg
# Saved image: C:\Users\K3000\Desktop\conversion test\new format\Images\01850201.MPG_01175.jpg, mask: C:\Users\K3000\Desktop\conversion test\new format\Masks\01850201.MPG_01175.png
# Saved image: C:\Users\K3000\Desktop\conversion test\new format\Images\01850201.MPG_01275.jpg, mask: C:\Users\K3000\Desktop\conversion test\new format\Masks\01850201.MPG_01275.png
# Saved image: C:\Users\K3000\Desktop\conversion test\new format\Images\01850201.MPG_01300.jpg, mask: C:\Users\K3000\Desktop\conversion test\new format\Masks\01850201.MPG_01300.png
# Saved image: C:\Users\K3000\Desktop\conversion test\new format\Images\01850201.MPG_01325.jpg, mask: C:\Users\K3000\Desktop\conversion test\new format\Masks\01850201.MPG_01325.png
# Saved image: C:\Users\K3000\Desktop\conversion test\new format\Images\01850201.MPG_01350.jpg, mask: C:\Users\K3000\Desktop\conversion test\new format\Masks\01850201.MPG_01350.png
# Saved image: C:\Users\K3000\Desktop\conversion test\new format\Images\01850201.MPG_01375.jpg, mask: C:\Users\K3000\Desktop\conversion test\new format\Masks\01850201.MPG_01375.png
# Saved image: C:\Users\K3000\Desktop\conversion test\new format\Images\01850201.MPG_01400.jpg, mask: C:\Users\K3000\Desktop\conversion test\new format\Masks\01850201.MPG_01400.png
# Saved image: C:\Users\K3000\Desktop\conversion test\new format\Images\01850201.MPG_01425.jpg, mask: C:\Users\K3000\Desktop\conversion test\new format\Masks\01850201.MPG_01425.png
# Saved image: C:\Users\K3000\Desktop\conversion test\new format\Images\01850201.MPG_01450.jpg, mask: C:\Users\K3000\Desktop\conversion test\new format\Masks\01850201.MPG_01450.png
# No annotations for 01475.jpg
# No annotations for 01500.jpg
# No annotations for 01525.jpg
# No annotations for 01550.jpg
# No annotations for 01575.jpg
# Saved image: C:\Users\K3000\Desktop\conversion test\new format\Images\01850201.MPG_01600.jpg, mask: C:\Users\K3000\Desktop\conversion test\new format\Masks\01850201.MPG_01600.png
# Saved image: C:\Users\K3000\Desktop\conversion test\new format\Images\01850201.MPG_01625.jpg, mask: C:\Users\K3000\Desktop\conversion test\new format\Masks\01850201.MPG_01625.png
# Saved image: C:\Users\K3000\Desktop\conversion test\new format\Images\01850201.MPG_01650.jpg, mask: C:\Users\K3000\Desktop\conversion test\new format\Masks\01850201.MPG_01650.png
# Saved image: C:\Users\K3000\Desktop\conversion test\new format\Images\01850201.MPG_01675.jpg, mask: C:\Users\K3000\Desktop\conversion test\new format\Masks\01850201.MPG_01675.png
# Saved image: C:\Users\K3000\Desktop\conversion test\new format\Images\01850201.MPG_01700.jpg, mask: C:\Users\K3000\Desktop\conversion test\new format\Masks\01850201.MPG_01700.png
# Saved image: C:\Users\K3000\Desktop\conversion test\new format\Images\01850201.MPG_01725.jpg, mask: C:\Users\K3000\Desktop\conversion test\new format\Masks\01850201.MPG_01725.png
# Saved image: C:\Users\K3000\Desktop\conversion test\new format\Images\01850201.MPG_01750.jpg, mask: C:\Users\K3000\Desktop\conversion test\new format\Masks\01850201.MPG_01750.png
# Saved image: C:\Users\K3000\Desktop\conversion test\new format\Images\01850201.MPG_01775.jpg, mask: C:\Users\K3000\Desktop\conversion test\new format\Masks\01850201.MPG_01775.png
# Saved image: C:\Users\K3000\Desktop\conversion test\new format\Images\01850201.MPG_01800.jpg, mask: C:\Users\K3000\Desktop\conversion test\new format\Masks\01850201.MPG_01800.png
# Saved image: C:\Users\K3000\Desktop\conversion test\new format\Images\01850201.MPG_01825.jpg, mask: C:\Users\K3000\Desktop\conversion test\new format\Masks\01850201.MPG_01825.png
# Saved image: C:\Users\K3000\Desktop\conversion test\new format\Images\01850201.MPG_01850.jpg, mask: C:\Users\K3000\Desktop\conversion test\new format\Masks\01850201.MPG_01850.png
# Saved image: C:\Users\K3000\Desktop\conversion test\new format\Images\01850201.MPG_01875.jpg, mask: C:\Users\K3000\Desktop\conversion test\new format\Masks\01850201.MPG_01875.png
# Saved image: C:\Users\K3000\Desktop\conversion test\new format\Images\01850201.MPG_01900.jpg, mask: C:\Users\K3000\Desktop\conversion test\new format\Masks\01850201.MPG_01900.png
# Saved image: C:\Users\K3000\Desktop\conversion test\new format\Images\01850201.MPG_01925.jpg, mask: C:\Users\K3000\Desktop\conversion test\new format\Masks\01850201.MPG_01925.png
# Saved image: C:\Users\K3000\Desktop\conversion test\new format\Images\01850201.MPG_01950.jpg, mask: C:\Users\K3000\Desktop\conversion test\new format\Masks\01850201.MPG_01950.png
# Saved image: C:\Users\K3000\Desktop\conversion test\new format\Images\01850201.MPG_02025.jpg, mask: C:\Users\K3000\Desktop\conversion test\new format\Masks\01850201.MPG_02025.png
# Saved image: C:\Users\K3000\Desktop\conversion test\new format\Images\01850201.MPG_02050.jpg, mask: C:\Users\K3000\Desktop\conversion test\new format\Masks\01850201.MPG_02050.png
# Saved image: C:\Users\K3000\Desktop\conversion test\new format\Images\01850201.MPG_02075.jpg, mask: C:\Users\K3000\Desktop\conversion test\new format\Masks\01850201.MPG_02075.png
# Saved image: C:\Users\K3000\Desktop\conversion test\new format\Images\01850201.MPG_02100.jpg, mask: C:\Users\K3000\Desktop\conversion test\new format\Masks\01850201.MPG_02100.png
# Saved image: C:\Users\K3000\Desktop\conversion test\new format\Images\01850201.MPG_02125.jpg, mask: C:\Users\K3000\Desktop\conversion test\new format\Masks\01850201.MPG_02125.png
# Saved image: C:\Users\K3000\Desktop\conversion test\new format\Images\01850201.MPG_02175.jpg, mask: C:\Users\K3000\Desktop\conversion test\new format\Masks\01850201.MPG_02175.png
# Saved image: C:\Users\K3000\Desktop\conversion test\new format\Images\01850201.MPG_02225.jpg, mask: C:\Users\K3000\Desktop\conversion test\new format\Masks\01850201.MPG_02225.png
# Saved image: C:\Users\K3000\Desktop\conversion test\new format\Images\01850201.MPG_02775.jpg, mask: C:\Users\K3000\Desktop\conversion test\new format\Masks\01850201.MPG_02775.png
# Saved image: C:\Users\K3000\Desktop\conversion test\new format\Images\01850201.MPG_02800.jpg, mask: C:\Users\K3000\Desktop\conversion test\new format\Masks\01850201.MPG_02800.png
# No annotations for 02825.jpg
# No annotations for 02850.jpg
# No annotations for 02875.jpg
# No annotations for 02900.jpg
# No annotations for 00000.jpg
# No annotations for 00025.jpg
# No annotations for 00300.jpg
# No annotations for 00400.jpg
# No annotations for 00425.jpg
# No annotations for 00450.jpg
# No annotations for 00475.jpg
# No annotations for 00500.jpg
# No annotations for 00525.jpg
# No annotations for 00550.jpg
# No annotations for 00575.jpg
# No annotations for 00600.jpg
# Saved image: C:\Users\K3000\Desktop\conversion test\new format\Images\04250100I.MPG_01675.jpg, mask: C:\Users\K3000\Desktop\conversion test\new format\Masks\04250100I.MPG_01675.png
# Saved image: C:\Users\K3000\Desktop\conversion test\new format\Images\04250100I.MPG_01700.jpg, mask: C:\Users\K3000\Desktop\conversion test\new format\Masks\04250100I.MPG_01700.png
# Saved image: C:\Users\K3000\Desktop\conversion test\new format\Images\04250100I.MPG_01725.jpg, mask: C:\Users\K3000\Desktop\conversion test\new format\Masks\04250100I.MPG_01725.png
# Saved image: C:\Users\K3000\Desktop\conversion test\new format\Images\04250100I.MPG_01750.jpg, mask: C:\Users\K3000\Desktop\conversion test\new format\Masks\04250100I.MPG_01750.png
# Saved image: C:\Users\K3000\Desktop\conversion test\new format\Images\04250100I.MPG_01775.jpg, mask: C:\Users\K3000\Desktop\conversion test\new format\Masks\04250100I.MPG_01775.png
# Saved image: C:\Users\K3000\Desktop\conversion test\new format\Images\04250100I.MPG_01800.jpg, mask: C:\Users\K3000\Desktop\conversion test\new format\Masks\04250100I.MPG_01800.png
# No annotations for 01825.jpg
# No annotations for 01850.jpg
# No annotations for 01875.jpg
# Saved image: C:\Users\K3000\Desktop\conversion test\new format\Images\04250100I.MPG_01900.jpg, mask: C:\Users\K3000\Desktop\conversion test\new format\Masks\04250100I.MPG_01900.png
# Saved image: C:\Users\K3000\Desktop\conversion test\new format\Images\04250100I.MPG_01925.jpg, mask: C:\Users\K3000\Desktop\conversion test\new format\Masks\04250100I.MPG_01925.png
# Saved image: C:\Users\K3000\Desktop\conversion test\new format\Images\04250100I.MPG_01950.jpg, mask: C:\Users\K3000\Desktop\conversion test\new format\Masks\04250100I.MPG_01950.png
# Saved image: C:\Users\K3000\Desktop\conversion test\new format\Images\04250100I.MPG_01975.jpg, mask: C:\Users\K3000\Desktop\conversion test\new format\Masks\04250100I.MPG_01975.png
# Saved image: C:\Users\K3000\Desktop\conversion test\new format\Images\04250100I.MPG_02000.jpg, mask: C:\Users\K3000\Desktop\conversion test\new format\Masks\04250100I.MPG_02000.png
# Saved image: C:\Users\K3000\Desktop\conversion test\new format\Images\04250100I.MPG_02025.jpg, mask: C:\Users\K3000\Desktop\conversion test\new format\Masks\04250100I.MPG_02025.png
# Saved image: C:\Users\K3000\Desktop\conversion test\new format\Images\04250100I.MPG_02050.jpg, mask: C:\Users\K3000\Desktop\conversion test\new format\Masks\04250100I.MPG_02050.png
# Saved image: C:\Users\K3000\Desktop\conversion test\new format\Images\04250100I.MPG_02100.jpg, mask: C:\Users\K3000\Desktop\conversion test\new format\Masks\04250100I.MPG_02100.png
# Saved image: C:\Users\K3000\Desktop\conversion test\new format\Images\04250100I.MPG_02125.jpg, mask: C:\Users\K3000\Desktop\conversion test\new format\Masks\04250100I.MPG_02125.png
# Saved image: C:\Users\K3000\Desktop\conversion test\new format\Images\04250100I.MPG_02150.jpg, mask: C:\Users\K3000\Desktop\conversion test\new format\Masks\04250100I.MPG_02150.png
# Saved image: C:\Users\K3000\Desktop\conversion test\new format\Images\04250100I.MPG_02175.jpg, mask: C:\Users\K3000\Desktop\conversion test\new format\Masks\04250100I.MPG_02175.png
# Saved image: C:\Users\K3000\Desktop\conversion test\new format\Images\04250100I.MPG_02575.jpg, mask: C:\Users\K3000\Desktop\conversion test\new format\Masks\04250100I.MPG_02575.png
# Saved image: C:\Users\K3000\Desktop\conversion test\new format\Images\04250100I.MPG_02600.jpg, mask: C:\Users\K3000\Desktop\conversion test\new format\Masks\04250100I.MPG_02600.png
# Saved image: C:\Users\K3000\Desktop\conversion test\new format\Images\04250100I.MPG_02625.jpg, mask: C:\Users\K3000\Desktop\conversion test\new format\Masks\04250100I.MPG_02625.png
# Saved image: C:\Users\K3000\Desktop\conversion test\new format\Images\04250100I.MPG_02650.jpg, mask: C:\Users\K3000\Desktop\conversion test\new format\Masks\04250100I.MPG_02650.png
# Saved image: C:\Users\K3000\Desktop\conversion test\new format\Images\04250100I.MPG_02675.jpg, mask: C:\Users\K3000\Desktop\conversion test\new format\Masks\04250100I.MPG_02675.png
# Saved image: C:\Users\K3000\Desktop\conversion test\new format\Images\04250100I.MPG_02700.jpg, mask: C:\Users\K3000\Desktop\conversion test\new format\Masks\04250100I.MPG_02700.png
# Saved image: C:\Users\K3000\Desktop\conversion test\new format\Images\04250100I.MPG_03175.jpg, mask: C:\Users\K3000\Desktop\conversion test\new format\Masks\04250100I.MPG_03175.png
# Saved image: C:\Users\K3000\Desktop\conversion test\new format\Images\04250100I.MPG_03200.jpg, mask: C:\Users\K3000\Desktop\conversion test\new format\Masks\04250100I.MPG_03200.png
# Saved image: C:\Users\K3000\Desktop\conversion test\new format\Images\04250100I.MPG_03225.jpg, mask: C:\Users\K3000\Desktop\conversion test\new format\Masks\04250100I.MPG_03225.png
# Saved image: C:\Users\K3000\Desktop\conversion test\new format\Images\04250100I.MPG_03250.jpg, mask: C:\Users\K3000\Desktop\conversion test\new format\Masks\04250100I.MPG_03250.png
# No annotations for 03275.jpg
# No annotations for 03300.jpg
# No annotations for 03325.jpg
# Saved image: C:\Users\K3000\Desktop\conversion test\new format\Images\04250150I.MPG_01950.jpg, mask: C:\Users\K3000\Desktop\conversion test\new format\Masks\04250150I.MPG_01950.png
# Saved image: C:\Users\K3000\Desktop\conversion test\new format\Images\04250150I.MPG_01975.jpg, mask: C:\Users\K3000\Desktop\conversion test\new format\Masks\04250150I.MPG_01975.png
# Saved image: C:\Users\K3000\Desktop\conversion test\new format\Images\04250150I.MPG_02000.jpg, mask: C:\Users\K3000\Desktop\conversion test\new format\Masks\04250150I.MPG_02000.png
# Saved image: C:\Users\K3000\Desktop\conversion test\new format\Images\04250150I.MPG_02025.jpg, mask: C:\Users\K3000\Desktop\conversion test\new format\Masks\04250150I.MPG_02025.png
# Saved image: C:\Users\K3000\Desktop\conversion test\new format\Images\04250150I.MPG_02050.jpg, mask: C:\Users\K3000\Desktop\conversion test\new format\Masks\04250150I.MPG_02050.png
# Saved image: C:\Users\K3000\Desktop\conversion test\new format\Images\04250150I.MPG_02075.jpg, mask: C:\Users\K3000\Desktop\conversion test\new format\Masks\04250150I.MPG_02075.png
# Saved image: C:\Users\K3000\Desktop\conversion test\new format\Images\04250150I.MPG_02100.jpg, mask: C:\Users\K3000\Desktop\conversion test\new format\Masks\04250150I.MPG_02100.png
# Saved image: C:\Users\K3000\Desktop\conversion test\new format\Images\04250150I.MPG_02125.jpg, mask: C:\Users\K3000\Desktop\conversion test\new format\Masks\04250150I.MPG_02125.png
# Saved image: C:\Users\K3000\Desktop\conversion test\new format\Images\04250150I.MPG_02150.jpg, mask: C:\Users\K3000\Desktop\conversion test\new format\Masks\04250150I.MPG_02150.png
# Saved image: C:\Users\K3000\Desktop\conversion test\new format\Images\04250150I.MPG_02175.jpg, mask: C:\Users\K3000\Desktop\conversion test\new format\Masks\04250150I.MPG_02175.png
# Saved image: C:\Users\K3000\Desktop\conversion test\new format\Images\04250150I.MPG_02200.jpg, mask: C:\Users\K3000\Desktop\conversion test\new format\Masks\04250150I.MPG_02200.png
# Saved image: C:\Users\K3000\Desktop\conversion test\new format\Images\04250150I.MPG_02225.jpg, mask: C:\Users\K3000\Desktop\conversion test\new format\Masks\04250150I.MPG_02225.png
# Saved image: C:\Users\K3000\Desktop\conversion test\new format\Images\04250150I.MPG_02250.jpg, mask: C:\Users\K3000\Desktop\conversion test\new format\Masks\04250150I.MPG_02250.png
# Saved image: C:\Users\K3000\Desktop\conversion test\new format\Images\04250150I.MPG_02275.jpg, mask: C:\Users\K3000\Desktop\conversion test\new format\Masks\04250150I.MPG_02275.png
# Saved image: C:\Users\K3000\Desktop\conversion test\new format\Images\04250150I.MPG_02300.jpg, mask: C:\Users\K3000\Desktop\conversion test\new format\Masks\04250150I.MPG_02300.png
# Saved image: C:\Users\K3000\Desktop\conversion test\new format\Images\04250150I.MPG_02325.jpg, mask: C:\Users\K3000\Desktop\conversion test\new format\Masks\04250150I.MPG_02325.png
# Saved image: C:\Users\K3000\Desktop\conversion test\new format\Images\04250150I.MPG_02350.jpg, mask: C:\Users\K3000\Desktop\conversion test\new format\Masks\04250150I.MPG_02350.png
# Saved image: C:\Users\K3000\Desktop\conversion test\new format\Images\04250150I.MPG_02375.jpg, mask: C:\Users\K3000\Desktop\conversion test\new format\Masks\04250150I.MPG_02375.png
# Saved image: C:\Users\K3000\Desktop\conversion test\new format\Images\04250150I.MPG_02400.jpg, mask: C:\Users\K3000\Desktop\conversion test\new format\Masks\04250150I.MPG_02400.png
# Saved image: C:\Users\K3000\Desktop\conversion test\new format\Images\04250150I.MPG_02425.jpg, mask: C:\Users\K3000\Desktop\conversion test\new format\Masks\04250150I.MPG_02425.png
# Saved image: C:\Users\K3000\Desktop\conversion test\new format\Images\04250150I.MPG_02450.jpg, mask: C:\Users\K3000\Desktop\conversion test\new format\Masks\04250150I.MPG_02450.png
# Saved image: C:\Users\K3000\Desktop\conversion test\new format\Images\04250150I.MPG_02475.jpg, mask: C:\Users\K3000\Desktop\conversion test\new format\Masks\04250150I.MPG_02475.png
# Saved image: C:\Users\K3000\Desktop\conversion test\new format\Images\04250150I.MPG_02500.jpg, mask: C:\Users\K3000\Desktop\conversion test\new format\Masks\04250150I.MPG_02500.png
# Saved image: C:\Users\K3000\Desktop\conversion test\new format\Images\04250150I.MPG_02525.jpg, mask: C:\Users\K3000\Desktop\conversion test\new format\Masks\04250150I.MPG_02525.png
# Saved image: C:\Users\K3000\Desktop\conversion test\new format\Images\04250150I.MPG_02550.jpg, mask: C:\Users\K3000\Desktop\conversion test\new format\Masks\04250150I.MPG_02550.png
# Saved image: C:\Users\K3000\Desktop\conversion test\new format\Images\04250150I.MPG_02575.jpg, mask: C:\Users\K3000\Desktop\conversion test\new format\Masks\04250150I.MPG_02575.png
# Saved image: C:\Users\K3000\Desktop\conversion test\new format\Images\04250150I.MPG_02600.jpg, mask: C:\Users\K3000\Desktop\conversion test\new format\Masks\04250150I.MPG_02600.png
# Saved image: C:\Users\K3000\Desktop\conversion test\new format\Images\04250150I.MPG_02625.jpg, mask: C:\Users\K3000\Desktop\conversion test\new format\Masks\04250150I.MPG_02625.png
# Saved image: C:\Users\K3000\Desktop\conversion test\new format\Images\04250150I.MPG_02650.jpg, mask: C:\Users\K3000\Desktop\conversion test\new format\Masks\04250150I.MPG_02650.png
# Saved image: C:\Users\K3000\Desktop\conversion test\new format\Images\04250150I.MPG_02675.jpg, mask: C:\Users\K3000\Desktop\conversion test\new format\Masks\04250150I.MPG_02675.png
# Saved image: C:\Users\K3000\Desktop\conversion test\new format\Images\04250150I.MPG_02700.jpg, mask: C:\Users\K3000\Desktop\conversion test\new format\Masks\04250150I.MPG_02700.png
# Saved image: C:\Users\K3000\Desktop\conversion test\new format\Images\04250150I.MPG_02725.jpg, mask: C:\Users\K3000\Desktop\conversion test\new format\Masks\04250150I.MPG_02725.png
# Saved image: C:\Users\K3000\Desktop\conversion test\new format\Images\04250150I.MPG_02750.jpg, mask: C:\Users\K3000\Desktop\conversion test\new format\Masks\04250150I.MPG_02750.png
# Saved image: C:\Users\K3000\Desktop\conversion test\new format\Images\04250150I.MPG_02775.jpg, mask: C:\Users\K3000\Desktop\conversion test\new format\Masks\04250150I.MPG_02775.png
# Saved image: C:\Users\K3000\Desktop\conversion test\new format\Images\04250150I.MPG_02800.jpg, mask: C:\Users\K3000\Desktop\conversion test\new format\Masks\04250150I.MPG_02800.png
# Saved image: C:\Users\K3000\Desktop\conversion test\new format\Images\04250150I.MPG_02825.jpg, mask: C:\Users\K3000\Desktop\conversion test\new format\Masks\04250150I.MPG_02825.png
# Saved image: C:\Users\K3000\Desktop\conversion test\new format\Images\04250150I.MPG_02850.jpg, mask: C:\Users\K3000\Desktop\conversion test\new format\Masks\04250150I.MPG_02850.png
# Saved image: C:\Users\K3000\Desktop\conversion test\new format\Images\04250150I.MPG_02875.jpg, mask: C:\Users\K3000\Desktop\conversion test\new format\Masks\04250150I.MPG_02875.png
# Saved image: C:\Users\K3000\Desktop\conversion test\new format\Images\04250150I.MPG_02900.jpg, mask: C:\Users\K3000\Desktop\conversion test\new format\Masks\04250150I.MPG_02900.png
# Saved image: C:\Users\K3000\Desktop\conversion test\new format\Images\04250150I.MPG_02925.jpg, mask: C:\Users\K3000\Desktop\conversion test\new format\Masks\04250150I.MPG_02925.png
# Saved image: C:\Users\K3000\Desktop\conversion test\new format\Images\04250150I.MPG_02950.jpg, mask: C:\Users\K3000\Desktop\conversion test\new format\Masks\04250150I.MPG_02950.png
# Saved image: C:\Users\K3000\Desktop\conversion test\new format\Images\04250150I.MPG_02975.jpg, mask: C:\Users\K3000\Desktop\conversion test\new format\Masks\04250150I.MPG_02975.png
# Saved image: C:\Users\K3000\Desktop\conversion test\new format\Images\04250150I.MPG_03000.jpg, mask: C:\Users\K3000\Desktop\conversion test\new format\Masks\04250150I.MPG_03000.png
# Saved image: C:\Users\K3000\Desktop\conversion test\new format\Images\04250150I.MPG_03025.jpg, mask: C:\Users\K3000\Desktop\conversion test\new format\Masks\04250150I.MPG_03025.png
# Saved image: C:\Users\K3000\Desktop\conversion test\new format\Images\04250150I.MPG_03050.jpg, mask: C:\Users\K3000\Desktop\conversion test\new format\Masks\04250150I.MPG_03050.png
# Saved image: C:\Users\K3000\Desktop\conversion test\new format\Images\04250150I.MPG_03075.jpg, mask: C:\Users\K3000\Desktop\conversion test\new format\Masks\04250150I.MPG_03075.png
# Saved image: C:\Users\K3000\Desktop\conversion test\new format\Images\04250150I.MPG_03100.jpg, mask: C:\Users\K3000\Desktop\conversion test\new format\Masks\04250150I.MPG_03100.png
# Saved image: C:\Users\K3000\Desktop\conversion test\new format\Images\04250150I.MPG_03125.jpg, mask: C:\Users\K3000\Desktop\conversion test\new format\Masks\04250150I.MPG_03125.png
# Saved image: C:\Users\K3000\Desktop\conversion test\new format\Images\04250150I.MPG_03150.jpg, mask: C:\Users\K3000\Desktop\conversion test\new format\Masks\04250150I.MPG_03150.png
# Saved image: C:\Users\K3000\Desktop\conversion test\new format\Images\04250150I.MPG_03175.jpg, mask: C:\Users\K3000\Desktop\conversion test\new format\Masks\04250150I.MPG_03175.png
# No annotations for 01000.jpg
# No annotations for 01025.jpg
# No annotations for 01050.jpg
# No annotations for 01075.jpg
# No annotations for 01100.jpg
# No annotations for 01125.jpg
# No annotations for 01150.jpg
# No annotations for 01175.jpg
# No annotations for 01200.jpg
# No annotations for 01225.jpg
# No annotations for 01250.jpg
# No annotations for 01275.jpg
# No annotations for 01300.jpg
# No annotations for 01325.jpg
# No annotations for 01350.jpg
# No annotations for 01375.jpg
# No annotations for 01400.jpg
# No annotations for 01425.jpg
# No annotations for 01450.jpg
# No annotations for 01475.jpg
# No annotations for 01500.jpg
# No annotations for 01525.jpg
# No annotations for 01550.jpg
# No annotations for 01575.jpg
# No annotations for 01600.jpg
# No annotations for 01625.jpg
# No annotations for 01650.jpg
# No annotations for 01675.jpg
# No annotations for 01700.jpg
# No annotations for 01725.jpg
# No annotations for 01750.jpg
# No annotations for 01775.jpg
# No annotations for 01800.jpg
# No annotations for 01825.jpg
# No annotations for 01850.jpg
# No annotations for 01875.jpg
# No annotations for 01900.jpg
# No annotations for 01925.jpg
# No annotations for 01950.jpg
# No annotations for 01975.jpg
# No annotations for 02000.jpg
# No annotations for 02025.jpg
# No annotations for 02050.jpg
# No annotations for 02075.jpg
# No annotations for 02100.jpg
# No annotations for 02125.jpg
# No annotations for 02150.jpg
# No annotations for 02175.jpg
# No annotations for 02200.jpg
# No annotations for 02225.jpg
# Saved image: C:\Users\K3000\Desktop\conversion test\new format\Images\04250300.MPG_01450.jpg, mask: C:\Users\K3000\Desktop\conversion test\new format\Masks\04250300.MPG_01450.png
# Saved image: C:\Users\K3000\Desktop\conversion test\new format\Images\04250300.MPG_01475.jpg, mask: C:\Users\K3000\Desktop\conversion test\new format\Masks\04250300.MPG_01475.png
# Saved image: C:\Users\K3000\Desktop\conversion test\new format\Images\04250300.MPG_01500.jpg, mask: C:\Users\K3000\Desktop\conversion test\new format\Masks\04250300.MPG_01500.png
# Saved image: C:\Users\K3000\Desktop\conversion test\new format\Images\04250300.MPG_01525.jpg, mask: C:\Users\K3000\Desktop\conversion test\new format\Masks\04250300.MPG_01525.png
# Saved image: C:\Users\K3000\Desktop\conversion test\new format\Images\04250300.MPG_01550.jpg, mask: C:\Users\K3000\Desktop\conversion test\new format\Masks\04250300.MPG_01550.png
# Saved image: C:\Users\K3000\Desktop\conversion test\new format\Images\04250300.MPG_01575.jpg, mask: C:\Users\K3000\Desktop\conversion test\new format\Masks\04250300.MPG_01575.png
# Saved image: C:\Users\K3000\Desktop\conversion test\new format\Images\04250300.MPG_01600.jpg, mask: C:\Users\K3000\Desktop\conversion test\new format\Masks\04250300.MPG_01600.png
# Saved image: C:\Users\K3000\Desktop\conversion test\new format\Images\04250300.MPG_01625.jpg, mask: C:\Users\K3000\Desktop\conversion test\new format\Masks\04250300.MPG_01625.png
# Saved image: C:\Users\K3000\Desktop\conversion test\new format\Images\04250300.MPG_01650.jpg, mask: C:\Users\K3000\Desktop\conversion test\new format\Masks\04250300.MPG_01650.png
# Saved image: C:\Users\K3000\Desktop\conversion test\new format\Images\04250300.MPG_01675.jpg, mask: C:\Users\K3000\Desktop\conversion test\new format\Masks\04250300.MPG_01675.png
# Saved image: C:\Users\K3000\Desktop\conversion test\new format\Images\04250300.MPG_01700.jpg, mask: C:\Users\K3000\Desktop\conversion test\new format\Masks\04250300.MPG_01700.png
# Saved image: C:\Users\K3000\Desktop\conversion test\new format\Images\04250300.MPG_01725.jpg, mask: C:\Users\K3000\Desktop\conversion test\new format\Masks\04250300.MPG_01725.png
# Saved image: C:\Users\K3000\Desktop\conversion test\new format\Images\04250300.MPG_01750.jpg, mask: C:\Users\K3000\Desktop\conversion test\new format\Masks\04250300.MPG_01750.png
# Saved image: C:\Users\K3000\Desktop\conversion test\new format\Images\04250300.MPG_01775.jpg, mask: C:\Users\K3000\Desktop\conversion test\new format\Masks\04250300.MPG_01775.png
# Saved image: C:\Users\K3000\Desktop\conversion test\new format\Images\04250300.MPG_01800.jpg, mask: C:\Users\K3000\Desktop\conversion test\new format\Masks\04250300.MPG_01800.png
# Saved image: C:\Users\K3000\Desktop\conversion test\new format\Images\04250300.MPG_01825.jpg, mask: C:\Users\K3000\Desktop\conversion test\new format\Masks\04250300.MPG_01825.png
# Saved image: C:\Users\K3000\Desktop\conversion test\new format\Images\04250300.MPG_01850.jpg, mask: C:\Users\K3000\Desktop\conversion test\new format\Masks\04250300.MPG_01850.png
# Saved image: C:\Users\K3000\Desktop\conversion test\new format\Images\04250300.MPG_01875.jpg, mask: C:\Users\K3000\Desktop\conversion test\new format\Masks\04250300.MPG_01875.png
# Saved image: C:\Users\K3000\Desktop\conversion test\new format\Images\04250300.MPG_01900.jpg, mask: C:\Users\K3000\Desktop\conversion test\new format\Masks\04250300.MPG_01900.png
# Saved image: C:\Users\K3000\Desktop\conversion test\new format\Images\04250300.MPG_01925.jpg, mask: C:\Users\K3000\Desktop\conversion test\new format\Masks\04250300.MPG_01925.png
# Saved image: C:\Users\K3000\Desktop\conversion test\new format\Images\04250300.MPG_01950.jpg, mask: C:\Users\K3000\Desktop\conversion test\new format\Masks\04250300.MPG_01950.png
# Saved image: C:\Users\K3000\Desktop\conversion test\new format\Images\04250300.MPG_01975.jpg, mask: C:\Users\K3000\Desktop\conversion test\new format\Masks\04250300.MPG_01975.png
# Saved image: C:\Users\K3000\Desktop\conversion test\new format\Images\04250300.MPG_02000.jpg, mask: C:\Users\K3000\Desktop\conversion test\new format\Masks\04250300.MPG_02000.png
# Saved image: C:\Users\K3000\Desktop\conversion test\new format\Images\04250300.MPG_02025.jpg, mask: C:\Users\K3000\Desktop\conversion test\new format\Masks\04250300.MPG_02025.png
# Saved image: C:\Users\K3000\Desktop\conversion test\new format\Images\04250300.MPG_02050.jpg, mask: C:\Users\K3000\Desktop\conversion test\new format\Masks\04250300.MPG_02050.png
# Saved image: C:\Users\K3000\Desktop\conversion test\new format\Images\04250300.MPG_02075.jpg, mask: C:\Users\K3000\Desktop\conversion test\new format\Masks\04250300.MPG_02075.png
# Saved image: C:\Users\K3000\Desktop\conversion test\new format\Images\04250300.MPG_02100.jpg, mask: C:\Users\K3000\Desktop\conversion test\new format\Masks\04250300.MPG_02100.png
# Saved image: C:\Users\K3000\Desktop\conversion test\new format\Images\04250300.MPG_02125.jpg, mask: C:\Users\K3000\Desktop\conversion test\new format\Masks\04250300.MPG_02125.png
# Saved image: C:\Users\K3000\Desktop\conversion test\new format\Images\04250300.MPG_02150.jpg, mask: C:\Users\K3000\Desktop\conversion test\new format\Masks\04250300.MPG_02150.png
# Saved image: C:\Users\K3000\Desktop\conversion test\new format\Images\04250300.MPG_02175.jpg, mask: C:\Users\K3000\Desktop\conversion test\new format\Masks\04250300.MPG_02175.png
# Saved image: C:\Users\K3000\Desktop\conversion test\new format\Images\04250300.MPG_02200.jpg, mask: C:\Users\K3000\Desktop\conversion test\new format\Masks\04250300.MPG_02200.png
# Saved image: C:\Users\K3000\Desktop\conversion test\new format\Images\04250300.MPG_02225.jpg, mask: C:\Users\K3000\Desktop\conversion test\new format\Masks\04250300.MPG_02225.png
# Saved image: C:\Users\K3000\Desktop\conversion test\new format\Images\04250300.MPG_02250.jpg, mask: C:\Users\K3000\Desktop\conversion test\new format\Masks\04250300.MPG_02250.png
# Saved image: C:\Users\K3000\Desktop\conversion test\new format\Images\04250300.MPG_02275.jpg, mask: C:\Users\K3000\Desktop\conversion test\new format\Masks\04250300.MPG_02275.png
# Saved image: C:\Users\K3000\Desktop\conversion test\new format\Images\04250300.MPG_02300.jpg, mask: C:\Users\K3000\Desktop\conversion test\new format\Masks\04250300.MPG_02300.png
# Saved image: C:\Users\K3000\Desktop\conversion test\new format\Images\04250300.MPG_02325.jpg, mask: C:\Users\K3000\Desktop\conversion test\new format\Masks\04250300.MPG_02325.png
# Saved image: C:\Users\K3000\Desktop\conversion test\new format\Images\04250300.MPG_02350.jpg, mask: C:\Users\K3000\Desktop\conversion test\new format\Masks\04250300.MPG_02350.png
# Saved image: C:\Users\K3000\Desktop\conversion test\new format\Images\04250300.MPG_02375.jpg, mask: C:\Users\K3000\Desktop\conversion test\new format\Masks\04250300.MPG_02375.png
# Saved image: C:\Users\K3000\Desktop\conversion test\new format\Images\04250300.MPG_02400.jpg, mask: C:\Users\K3000\Desktop\conversion test\new format\Masks\04250300.MPG_02400.png
# Saved image: C:\Users\K3000\Desktop\conversion test\new format\Images\04250300.MPG_02425.jpg, mask: C:\Users\K3000\Desktop\conversion test\new format\Masks\04250300.MPG_02425.png
# Saved image: C:\Users\K3000\Desktop\conversion test\new format\Images\04250300.MPG_02450.jpg, mask: C:\Users\K3000\Desktop\conversion test\new format\Masks\04250300.MPG_02450.png
# Saved image: C:\Users\K3000\Desktop\conversion test\new format\Images\04250300.MPG_02475.jpg, mask: C:\Users\K3000\Desktop\conversion test\new format\Masks\04250300.MPG_02475.png
# Saved image: C:\Users\K3000\Desktop\conversion test\new format\Images\04250300.MPG_02500.jpg, mask: C:\Users\K3000\Desktop\conversion test\new format\Masks\04250300.MPG_02500.png
# Saved image: C:\Users\K3000\Desktop\conversion test\new format\Images\04250300.MPG_02525.jpg, mask: C:\Users\K3000\Desktop\conversion test\new format\Masks\04250300.MPG_02525.png
# Saved image: C:\Users\K3000\Desktop\conversion test\new format\Images\04250300.MPG_02550.jpg, mask: C:\Users\K3000\Desktop\conversion test\new format\Masks\04250300.MPG_02550.png
# Saved image: C:\Users\K3000\Desktop\conversion test\new format\Images\04250300.MPG_02575.jpg, mask: C:\Users\K3000\Desktop\conversion test\new format\Masks\04250300.MPG_02575.png
# Saved image: C:\Users\K3000\Desktop\conversion test\new format\Images\04250300.MPG_02600.jpg, mask: C:\Users\K3000\Desktop\conversion test\new format\Masks\04250300.MPG_02600.png
# Saved image: C:\Users\K3000\Desktop\conversion test\new format\Images\04250300.MPG_02625.jpg, mask: C:\Users\K3000\Desktop\conversion test\new format\Masks\04250300.MPG_02625.png
# Saved image: C:\Users\K3000\Desktop\conversion test\new format\Images\04250300.MPG_02650.jpg, mask: C:\Users\K3000\Desktop\conversion test\new format\Masks\04250300.MPG_02650.png
# Saved image: C:\Users\K3000\Desktop\conversion test\new format\Images\04250300.MPG_02675.jpg, mask: C:\Users\K3000\Desktop\conversion test\new format\Masks\04250300.MPG_02675.png
# Saved image: C:\Users\K3000\Desktop\conversion test\new format\Images\04250350.MPG_01125.jpg, mask: C:\Users\K3000\Desktop\conversion test\new format\Masks\04250350.MPG_01125.png
# Saved image: C:\Users\K3000\Desktop\conversion test\new format\Images\04250350.MPG_01150.jpg, mask: C:\Users\K3000\Desktop\conversion test\new format\Masks\04250350.MPG_01150.png
# Saved image: C:\Users\K3000\Desktop\conversion test\new format\Images\04250350.MPG_01175.jpg, mask: C:\Users\K3000\Desktop\conversion test\new format\Masks\04250350.MPG_01175.png
# Saved image: C:\Users\K3000\Desktop\conversion test\new format\Images\04250350.MPG_01200.jpg, mask: C:\Users\K3000\Desktop\conversion test\new format\Masks\04250350.MPG_01200.png
# Saved image: C:\Users\K3000\Desktop\conversion test\new format\Images\04250350.MPG_01225.jpg, mask: C:\Users\K3000\Desktop\conversion test\new format\Masks\04250350.MPG_01225.png
# Saved image: C:\Users\K3000\Desktop\conversion test\new format\Images\04250350.MPG_01250.jpg, mask: C:\Users\K3000\Desktop\conversion test\new format\Masks\04250350.MPG_01250.png
# Saved image: C:\Users\K3000\Desktop\conversion test\new format\Images\04250350.MPG_01275.jpg, mask: C:\Users\K3000\Desktop\conversion test\new format\Masks\04250350.MPG_01275.png
# Saved image: C:\Users\K3000\Desktop\conversion test\new format\Images\04250350.MPG_01300.jpg, mask: C:\Users\K3000\Desktop\conversion test\new format\Masks\04250350.MPG_01300.png
# Saved image: C:\Users\K3000\Desktop\conversion test\new format\Images\04250350.MPG_01325.jpg, mask: C:\Users\K3000\Desktop\conversion test\new format\Masks\04250350.MPG_01325.png
# Saved image: C:\Users\K3000\Desktop\conversion test\new format\Images\04250350.MPG_01350.jpg, mask: C:\Users\K3000\Desktop\conversion test\new format\Masks\04250350.MPG_01350.png
# Saved image: C:\Users\K3000\Desktop\conversion test\new format\Images\04250350.MPG_01375.jpg, mask: C:\Users\K3000\Desktop\conversion test\new format\Masks\04250350.MPG_01375.png
# Saved image: C:\Users\K3000\Desktop\conversion test\new format\Images\04250350.MPG_01400.jpg, mask: C:\Users\K3000\Desktop\conversion test\new format\Masks\04250350.MPG_01400.png
# Saved image: C:\Users\K3000\Desktop\conversion test\new format\Images\04250350.MPG_01425.jpg, mask: C:\Users\K3000\Desktop\conversion test\new format\Masks\04250350.MPG_01425.png
# Saved image: C:\Users\K3000\Desktop\conversion test\new format\Images\04250350.MPG_01450.jpg, mask: C:\Users\K3000\Desktop\conversion test\new format\Masks\04250350.MPG_01450.png
# Saved image: C:\Users\K3000\Desktop\conversion test\new format\Images\04250350.MPG_01475.jpg, mask: C:\Users\K3000\Desktop\conversion test\new format\Masks\04250350.MPG_01475.png
# Saved image: C:\Users\K3000\Desktop\conversion test\new format\Images\04250350.MPG_01500.jpg, mask: C:\Users\K3000\Desktop\conversion test\new format\Masks\04250350.MPG_01500.png
# No annotations for 01525.jpg
# Saved image: C:\Users\K3000\Desktop\conversion test\new format\Images\04250350.MPG_01550.jpg, mask: C:\Users\K3000\Desktop\conversion test\new format\Masks\04250350.MPG_01550.png
# Saved image: C:\Users\K3000\Desktop\conversion test\new format\Images\04250350.MPG_01575.jpg, mask: C:\Users\K3000\Desktop\conversion test\new format\Masks\04250350.MPG_01575.png
# Saved image: C:\Users\K3000\Desktop\conversion test\new format\Images\04250350.MPG_01600.jpg, mask: C:\Users\K3000\Desktop\conversion test\new format\Masks\04250350.MPG_01600.png
# Saved image: C:\Users\K3000\Desktop\conversion test\new format\Images\04250350.MPG_01625.jpg, mask: C:\Users\K3000\Desktop\conversion test\new format\Masks\04250350.MPG_01625.png
# Saved image: C:\Users\K3000\Desktop\conversion test\new format\Images\04250350.MPG_01650.jpg, mask: C:\Users\K3000\Desktop\conversion test\new format\Masks\04250350.MPG_01650.png
# Saved image: C:\Users\K3000\Desktop\conversion test\new format\Images\04250350.MPG_01675.jpg, mask: C:\Users\K3000\Desktop\conversion test\new format\Masks\04250350.MPG_01675.png
# Saved image: C:\Users\K3000\Desktop\conversion test\new format\Images\04250350.MPG_01700.jpg, mask: C:\Users\K3000\Desktop\conversion test\new format\Masks\04250350.MPG_01700.png
# Saved image: C:\Users\K3000\Desktop\conversion test\new format\Images\04250350.MPG_01725.jpg, mask: C:\Users\K3000\Desktop\conversion test\new format\Masks\04250350.MPG_01725.png
# Saved image: C:\Users\K3000\Desktop\conversion test\new format\Images\04250350.MPG_01750.jpg, mask: C:\Users\K3000\Desktop\conversion test\new format\Masks\04250350.MPG_01750.png
# Saved image: C:\Users\K3000\Desktop\conversion test\new format\Images\04250350.MPG_01775.jpg, mask: C:\Users\K3000\Desktop\conversion test\new format\Masks\04250350.MPG_01775.png
# No annotations for 01800.jpg
# No annotations for 01825.jpg
# No annotations for 01850.jpg
# No annotations for 01875.jpg
# No annotations for 01900.jpg
# No annotations for 01925.jpg
# No annotations for 01950.jpg
# No annotations for 01975.jpg
# No annotations for 02000.jpg
# No annotations for 02025.jpg
# No annotations for 02050.jpg
# No annotations for 02075.jpg
# No annotations for 02100.jpg
# No annotations for 02125.jpg
# No annotations for 02150.jpg
# No annotations for 02175.jpg
# No annotations for 02200.jpg
# No annotations for 02225.jpg
# No annotations for 02250.jpg
# No annotations for 02275.jpg
# No annotations for 02300.jpg
# No annotations for 02325.jpg
# No annotations for 02350.jpg
# Saved image: C:\Users\K3000\Desktop\conversion test\new format\Images\04250550.MPG_02850.jpg, mask: C:\Users\K3000\Desktop\conversion test\new format\Masks\04250550.MPG_02850.png
# Saved image: C:\Users\K3000\Desktop\conversion test\new format\Images\04250550.MPG_02875.jpg, mask: C:\Users\K3000\Desktop\conversion test\new format\Masks\04250550.MPG_02875.png
# Saved image: C:\Users\K3000\Desktop\conversion test\new format\Images\04250550.MPG_02900.jpg, mask: C:\Users\K3000\Desktop\conversion test\new format\Masks\04250550.MPG_02900.png
# Saved image: C:\Users\K3000\Desktop\conversion test\new format\Images\04250550.MPG_02925.jpg, mask: C:\Users\K3000\Desktop\conversion test\new format\Masks\04250550.MPG_02925.png
# Saved image: C:\Users\K3000\Desktop\conversion test\new format\Images\04250550.MPG_02950.jpg, mask: C:\Users\K3000\Desktop\conversion test\new format\Masks\04250550.MPG_02950.png
# Saved image: C:\Users\K3000\Desktop\conversion test\new format\Images\04250550.MPG_02975.jpg, mask: C:\Users\K3000\Desktop\conversion test\new format\Masks\04250550.MPG_02975.png
# Saved image: C:\Users\K3000\Desktop\conversion test\new format\Images\04250550.MPG_03000.jpg, mask: C:\Users\K3000\Desktop\conversion test\new format\Masks\04250550.MPG_03000.png
# Saved image: C:\Users\K3000\Desktop\conversion test\new format\Images\04250550.MPG_03025.jpg, mask: C:\Users\K3000\Desktop\conversion test\new format\Masks\04250550.MPG_03025.png
# Saved image: C:\Users\K3000\Desktop\conversion test\new format\Images\04250550.MPG_03050.jpg, mask: C:\Users\K3000\Desktop\conversion test\new format\Masks\04250550.MPG_03050.png
# Saved image: C:\Users\K3000\Desktop\conversion test\new format\Images\04250550.MPG_03075.jpg, mask: C:\Users\K3000\Desktop\conversion test\new format\Masks\04250550.MPG_03075.png
# Saved image: C:\Users\K3000\Desktop\conversion test\new format\Images\04250550.MPG_03100.jpg, mask: C:\Users\K3000\Desktop\conversion test\new format\Masks\04250550.MPG_03100.png
# Saved image: C:\Users\K3000\Desktop\conversion test\new format\Images\04250550.MPG_03125.jpg, mask: C:\Users\K3000\Desktop\conversion test\new format\Masks\04250550.MPG_03125.png
# Saved image: C:\Users\K3000\Desktop\conversion test\new format\Images\04250550.MPG_03150.jpg, mask: C:\Users\K3000\Desktop\conversion test\new format\Masks\04250550.MPG_03150.png
# Saved image: C:\Users\K3000\Desktop\conversion test\new format\Images\04250550.MPG_03175.jpg, mask: C:\Users\K3000\Desktop\conversion test\new format\Masks\04250550.MPG_03175.png
# Saved image: C:\Users\K3000\Desktop\conversion test\new format\Images\04250550.MPG_03200.jpg, mask: C:\Users\K3000\Desktop\conversion test\new format\Masks\04250550.MPG_03200.png
# Saved image: C:\Users\K3000\Desktop\conversion test\new format\Images\04250550.MPG_03225.jpg, mask: C:\Users\K3000\Desktop\conversion test\new format\Masks\04250550.MPG_03225.png
# Saved image: C:\Users\K3000\Desktop\conversion test\new format\Images\04250550.MPG_03250.jpg, mask: C:\Users\K3000\Desktop\conversion test\new format\Masks\04250550.MPG_03250.png
# Saved image: C:\Users\K3000\Desktop\conversion test\new format\Images\04250550.MPG_03275.jpg, mask: C:\Users\K3000\Desktop\conversion test\new format\Masks\04250550.MPG_03275.png
# Saved image: C:\Users\K3000\Desktop\conversion test\new format\Images\04250550.MPG_03300.jpg, mask: C:\Users\K3000\Desktop\conversion test\new format\Masks\04250550.MPG_03300.png
# Saved image: C:\Users\K3000\Desktop\conversion test\new format\Images\04250550.MPG_03325.jpg, mask: C:\Users\K3000\Desktop\conversion test\new format\Masks\04250550.MPG_03325.png
# Saved image: C:\Users\K3000\Desktop\conversion test\new format\Images\04250550.MPG_03350.jpg, mask: C:\Users\K3000\Desktop\conversion test\new format\Masks\04250550.MPG_03350.png
# ...
# Saved image: C:\Users\K3000\Desktop\conversion test\new format\Images\_6011U10243434__.mpg_02500.jpg, mask: C:\Users\K3000\Desktop\conversion test\new format\Masks\_6011U10243434__.mpg_02500.png
# Saved image: C:\Users\K3000\Desktop\conversion test\new format\Images\_6011U10243434__.mpg_02525.jpg, mask: C:\Users\K3000\Desktop\conversion test\new format\Masks\_6011U10243434__.mpg_02525.png
# Saved image: C:\Users\K3000\Desktop\conversion test\new format\Images\_6011U10243434__.mpg_02550.jpg, mask: C:\Users\K3000\Desktop\conversion test\new format\Masks\_6011U10243434__.mpg_02550.png
# Saved image: C:\Users\K3000\Desktop\conversion test\new format\Images\_6011U10243434__.mpg_02575.jpg, mask: C:\Users\K3000\Desktop\conversion test\new format\Masks\_6011U10243434__.mpg_02575.png
# Saved image: C:\Users\K3000\Desktop\conversion test\new format\Images\_6011U10243434__.mpg_02600.jpg, mask: C:\Users\K3000\Desktop\conversion test\new format\Masks\_6011U10243434__.mpg_02600.png
# Saved image: C:\Users\K3000\Desktop\conversion test\new format\Images\_6011U10243434__.mpg_02625.jpg, mask: C:\Users\K3000\Desktop\conversion test\new format\Masks\_6011U10243434__.mpg_02625.png
# Saved image: C:\Users\K3000\Desktop\conversion test\new format\Images\_6011U10243434__.mpg_02700.jpg, mask: C:\Users\K3000\Desktop\conversion test\new format\Masks\_6011U10243434__.mpg_02700.png
# Saved image: C:\Users\K3000\Desktop\conversion test\new format\Images\_6011U10243434__.mpg_02725.jpg, mask: C:\Users\K3000\Desktop\conversion test\new format\Masks\_6011U10243434__.mpg_02725.png
# Saved image: C:\Users\K3000\Desktop\conversion test\new format\Images\_6011U10243434__.mpg_02750.jpg, mask: C:\Users\K3000\Desktop\conversion test\new format\Masks\_6011U10243434__.mpg_02750.png
# Saved image: C:\Users\K3000\Desktop\conversion test\new format\Images\_6011U10243434__.mpg_02775.jpg, mask: C:\Users\K3000\Desktop\conversion test\new format\Masks\_6011U10243434__.mpg_02775.png
# Saved image: C:\Users\K3000\Desktop\conversion test\new format\Images\_6011U10243434__.mpg_02800.jpg, mask: C:\Users\K3000\Desktop\conversion test\new format\Masks\_6011U10243434__.mpg_02800.png
# Saved image: C:\Users\K3000\Desktop\conversion test\new format\Images\_6011U10243434__.mpg_02825.jpg, mask: C:\Users\K3000\Desktop\conversion test\new format\Masks\_6011U10243434__.mpg_02825.png
# Saved image: C:\Users\K3000\Desktop\conversion test\new format\Images\_6011U10243434__.mpg_02850.jpg, mask: C:\Users\K3000\Desktop\conversion test\new format\Masks\_6011U10243434__.mpg_02850.png
# Saved image: C:\Users\K3000\Desktop\conversion test\new format\Images\_6011U10243434__.mpg_02875.jpg, mask: C:\Users\K3000\Desktop\conversion test\new format\Masks\_6011U10243434__.mpg_02875.png
# Saved image: C:\Users\K3000\Desktop\conversion test\new format\Images\_6011U10243434__.mpg_02900.jpg, mask: C:\Users\K3000\Desktop\conversion test\new format\Masks\_6011U10243434__.mpg_02900.png
# Saved image: C:\Users\K3000\Desktop\conversion test\new format\Images\_6011U10243434__.mpg_02925.jpg, mask: C:\Users\K3000\Desktop\conversion test\new format\Masks\_6011U10243434__.mpg_02925.png
# No annotations for 02950.jpg
# No annotations for 02975.jpg
# No annotations for 03000.jpg
# No annotations for 03025.jpg
# No annotations for 03050.jpg
# Saved image: C:\Users\K3000\Desktop\conversion test\new format\Images\_6024D08503434__.mpg_00025.jpg, mask: C:\Users\K3000\Desktop\conversion test\new format\Masks\_6024D08503434__.mpg_00025.png
# Saved image: C:\Users\K3000\Desktop\conversion test\new format\Images\_6024D08503434__.mpg_00050.jpg, mask: C:\Users\K3000\Desktop\conversion test\new format\Masks\_6024D08503434__.mpg_00050.png
# Saved image: C:\Users\K3000\Desktop\conversion test\new format\Images\_6024D08503434__.mpg_00075.jpg, mask: C:\Users\K3000\Desktop\conversion test\new format\Masks\_6024D08503434__.mpg_00075.png
# Saved image: C:\Users\K3000\Desktop\conversion test\new format\Images\_6024D08503434__.mpg_00100.jpg, mask: C:\Users\K3000\Desktop\conversion test\new format\Masks\_6024D08503434__.mpg_00100.png
# Saved image: C:\Users\K3000\Desktop\conversion test\new format\Images\_6024D08503434__.mpg_00125.jpg, mask: C:\Users\K3000\Desktop\conversion test\new format\Masks\_6024D08503434__.mpg_00125.png
# Saved image: C:\Users\K3000\Desktop\conversion test\new format\Images\_6024D08503434__.mpg_00150.jpg, mask: C:\Users\K3000\Desktop\conversion test\new format\Masks\_6024D08503434__.mpg_00150.png
# Saved image: C:\Users\K3000\Desktop\conversion test\new format\Images\_6024D08503434__.mpg_00175.jpg, mask: C:\Users\K3000\Desktop\conversion test\new format\Masks\_6024D08503434__.mpg_00175.png
# Saved image: C:\Users\K3000\Desktop\conversion test\new format\Images\_6024D08503434__.mpg_00200.jpg, mask: C:\Users\K3000\Desktop\conversion test\new format\Masks\_6024D08503434__.mpg_00200.png
# Saved image: C:\Users\K3000\Desktop\conversion test\new format\Images\_6024D08503434__.mpg_00225.jpg, mask: C:\Users\K3000\Desktop\conversion test\new format\Masks\_6024D08503434__.mpg_00225.png
# Saved image: C:\Users\K3000\Desktop\conversion test\new format\Images\_6024D08503434__.mpg_00250.jpg, mask: C:\Users\K3000\Desktop\conversion test\new format\Masks\_6024D08503434__.mpg_00250.png
# Saved image: C:\Users\K3000\Desktop\conversion test\new format\Images\_6024D08503434__.mpg_00275.jpg, mask: C:\Users\K3000\Desktop\conversion test\new format\Masks\_6024D08503434__.mpg_00275.png
# Saved image: C:\Users\K3000\Desktop\conversion test\new format\Images\_6024D08503434__.mpg_00300.jpg, mask: C:\Users\K3000\Desktop\conversion test\new format\Masks\_6024D08503434__.mpg_00300.png
# Saved image: C:\Users\K3000\Desktop\conversion test\new format\Images\_6024D08503434__.mpg_00325.jpg, mask: C:\Users\K3000\Desktop\conversion test\new format\Masks\_6024D08503434__.mpg_00325.png
# Saved image: C:\Users\K3000\Desktop\conversion test\new format\Images\_6024D08503434__.mpg_00350.jpg, mask: C:\Users\K3000\Desktop\conversion test\new format\Masks\_6024D08503434__.mpg_00350.png
# Saved image: C:\Users\K3000\Desktop\conversion test\new format\Images\_6024D08503434__.mpg_00375.jpg, mask: C:\Users\K3000\Desktop\conversion test\new format\Masks\_6024D08503434__.mpg_00375.png
# Saved image: C:\Users\K3000\Desktop\conversion test\new format\Images\_6024D08503434__.mpg_00400.jpg, mask: C:\Users\K3000\Desktop\conversion test\new format\Masks\_6024D08503434__.mpg_00400.png
# Saved image: C:\Users\K3000\Desktop\conversion test\new format\Images\_6024D08503434__.mpg_00425.jpg, mask: C:\Users\K3000\Desktop\conversion test\new format\Masks\_6024D08503434__.mpg_00425.png
# Saved image: C:\Users\K3000\Desktop\conversion test\new format\Images\_6024D08503434__.mpg_00450.jpg, mask: C:\Users\K3000\Desktop\conversion test\new format\Masks\_6024D08503434__.mpg_00450.png
# Saved image: C:\Users\K3000\Desktop\conversion test\new format\Images\_6024D08503434__.mpg_00475.jpg, mask: C:\Users\K3000\Desktop\conversion test\new format\Masks\_6024D08503434__.mpg_00475.png
# Saved image: C:\Users\K3000\Desktop\conversion test\new format\Images\_6024D08503434__.mpg_00500.jpg, mask: C:\Users\K3000\Desktop\conversion test\new format\Masks\_6024D08503434__.mpg_00500.png
# Saved image: C:\Users\K3000\Desktop\conversion test\new format\Images\_6024D08503434__.mpg_00525.jpg, mask: C:\Users\K3000\Desktop\conversion test\new format\Masks\_6024D08503434__.mpg_00525.png
# Saved image: C:\Users\K3000\Desktop\conversion test\new format\Images\_6024D08503434__.mpg_00550.jpg, mask: C:\Users\K3000\Desktop\conversion test\new format\Masks\_6024D08503434__.mpg_00550.png
# Saved image: C:\Users\K3000\Desktop\conversion test\new format\Images\_6024D08503434__.mpg_00575.jpg, mask: C:\Users\K3000\Desktop\conversion test\new format\Masks\_6024D08503434__.mpg_00575.png
# Saved image: C:\Users\K3000\Desktop\conversion test\new format\Images\_6024D08503434__.mpg_00600.jpg, mask: C:\Users\K3000\Desktop\conversion test\new format\Masks\_6024D08503434__.mpg_00600.png
# Saved image: C:\Users\K3000\Desktop\conversion test\new format\Images\_6024D08503434__.mpg_00625.jpg, mask: C:\Users\K3000\Desktop\conversion test\new format\Masks\_6024D08503434__.mpg_00625.png
# Saved image: C:\Users\K3000\Desktop\conversion test\new format\Images\_6024D08503434__.mpg_00650.jpg, mask: C:\Users\K3000\Desktop\conversion test\new format\Masks\_6024D08503434__.mpg_00650.png
# Saved image: C:\Users\K3000\Desktop\conversion test\new format\Images\_6024D08503434__.mpg_00675.jpg, mask: C:\Users\K3000\Desktop\conversion test\new format\Masks\_6024D08503434__.mpg_00675.png
# Saved image: C:\Users\K3000\Desktop\conversion test\new format\Images\_6024D08503434__.mpg_00700.jpg, mask: C:\Users\K3000\Desktop\conversion test\new format\Masks\_6024D08503434__.mpg_00700.png
# Saved image: C:\Users\K3000\Desktop\conversion test\new format\Images\_6024D08503434__.mpg_00725.jpg, mask: C:\Users\K3000\Desktop\conversion test\new format\Masks\_6024D08503434__.mpg_00725.png
# Saved image: C:\Users\K3000\Desktop\conversion test\new format\Images\_6024D08503434__.mpg_00750.jpg, mask: C:\Users\K3000\Desktop\conversion test\new format\Masks\_6024D08503434__.mpg_00750.png
# Saved image: C:\Users\K3000\Desktop\conversion test\new format\Images\_6024D08503434__.mpg_00775.jpg, mask: C:\Users\K3000\Desktop\conversion test\new format\Masks\_6024D08503434__.mpg_00775.png
# Saved image: C:\Users\K3000\Desktop\conversion test\new format\Images\_6024D08503434__.mpg_00800.jpg, mask: C:\Users\K3000\Desktop\conversion test\new format\Masks\_6024D08503434__.mpg_00800.png
# Saved image: C:\Users\K3000\Desktop\conversion test\new format\Images\_6024D08503434__.mpg_00825.jpg, mask: C:\Users\K3000\Desktop\conversion test\new format\Masks\_6024D08503434__.mpg_00825.png
# Saved image: C:\Users\K3000\Desktop\conversion test\new format\Images\_6024D08503434__.mpg_00850.jpg, mask: C:\Users\K3000\Desktop\conversion test\new format\Masks\_6024D08503434__.mpg_00850.png
# Saved image: C:\Users\K3000\Desktop\conversion test\new format\Images\_6024D08503434__.mpg_00875.jpg, mask: C:\Users\K3000\Desktop\conversion test\new format\Masks\_6024D08503434__.mpg_00875.png
# Saved image: C:\Users\K3000\Desktop\conversion test\new format\Images\_6024D08503434__.mpg_00900.jpg, mask: C:\Users\K3000\Desktop\conversion test\new format\Masks\_6024D08503434__.mpg_00900.png
# Saved image: C:\Users\K3000\Desktop\conversion test\new format\Images\_6024D08503434__.mpg_00925.jpg, mask: C:\Users\K3000\Desktop\conversion test\new format\Masks\_6024D08503434__.mpg_00925.png
# Saved image: C:\Users\K3000\Desktop\conversion test\new format\Images\_6024D08503434__.mpg_00950.jpg, mask: C:\Users\K3000\Desktop\conversion test\new format\Masks\_6024D08503434__.mpg_00950.png
# Saved image: C:\Users\K3000\Desktop\conversion test\new format\Images\_6024D08503434__.mpg_00975.jpg, mask: C:\Users\K3000\Desktop\conversion test\new format\Masks\_6024D08503434__.mpg_00975.png
# Saved image: C:\Users\K3000\Desktop\conversion test\new format\Images\_6024D08503434__.mpg_01000.jpg, mask: C:\Users\K3000\Desktop\conversion test\new format\Masks\_6024D08503434__.mpg_01000.png
# Saved image: C:\Users\K3000\Desktop\conversion test\new format\Images\_6024D08503434__.mpg_01025.jpg, mask: C:\Users\K3000\Desktop\conversion test\new format\Masks\_6024D08503434__.mpg_01025.png
# Saved image: C:\Users\K3000\Desktop\conversion test\new format\Images\_6024D08503434__.mpg_01050.jpg, mask: C:\Users\K3000\Desktop\conversion test\new format\Masks\_6024D08503434__.mpg_01050.png
# Saved image: C:\Users\K3000\Desktop\conversion test\new format\Images\_6024D08503434__.mpg_01075.jpg, mask: C:\Users\K3000\Desktop\conversion test\new format\Masks\_6024D08503434__.mpg_01075.png
# Saved image: C:\Users\K3000\Desktop\conversion test\new format\Images\_6024D08503434__.mpg_01100.jpg, mask: C:\Users\K3000\Desktop\conversion test\new format\Masks\_6024D08503434__.mpg_01100.png
# Saved image: C:\Users\K3000\Desktop\conversion test\new format\Images\_6024D08503434__.mpg_01125.jpg, mask: C:\Users\K3000\Desktop\conversion test\new format\Masks\_6024D08503434__.mpg_01125.png
# Saved image: C:\Users\K3000\Desktop\conversion test\new format\Images\_6024D08503434__.mpg_01150.jpg, mask: C:\Users\K3000\Desktop\conversion test\new format\Masks\_6024D08503434__.mpg_01150.png
# Saved image: C:\Users\K3000\Desktop\conversion test\new format\Images\_6024D08503434__.mpg_01175.jpg, mask: C:\Users\K3000\Desktop\conversion test\new format\Masks\_6024D08503434__.mpg_01175.png
# Saved image: C:\Users\K3000\Desktop\conversion test\new format\Images\_6024D08503434__.mpg_01200.jpg, mask: C:\Users\K3000\Desktop\conversion test\new format\Masks\_6024D08503434__.mpg_01200.png
# Saved image: C:\Users\K3000\Desktop\conversion test\new format\Images\_6024D08503434__.mpg_01225.jpg, mask: C:\Users\K3000\Desktop\conversion test\new format\Masks\_6024D08503434__.mpg_01225.png
# Saved image: C:\Users\K3000\Desktop\conversion test\new format\Images\_6024D08503434__.mpg_01250.jpg, mask: C:\Users\K3000\Desktop\conversion test\new format\Masks\_6024D08503434__.mpg_01250.png
# ---------------------------------------------------------------------------
# JSONDecodeError                           Traceback (most recent call last)
# Cell In[43], line 74
#      69             mask.save(mask_output_path)
#      70             print(f"Saved image: {image_output_path}, mask: {mask_output_path}")
# ---> 74 generate_masks(labeled_dataset_path, formatted_dataset_path)
#
# Cell In[43], line 23, in generate_masks(dataset_path, output_path)
#      21 # Parse the JSON
#      22 with open(json_path, 'r') as f:
# ---> 23     annotations = json.load(f)
#      25 # Locate the source images directory
#      26 images_path = os.path.join(video_path, "source images")
#
# File c:\Users\K3000\anaconda3\envs\sam2\Lib\json\__init__.py:293, in load(fp, cls, object_hook, parse_float, parse_int, parse_constant, object_pairs_hook, **kw)
#     274 def load(fp, *, cls=None, object_hook=None, parse_float=None,
#     275         parse_int=None, parse_constant=None, object_pairs_hook=None, **kw):
#     276     """Deserialize ``fp`` (a ``.read()``-supporting file-like object containing
#     277     a JSON document) to a Python object.
#     278
#    (...)
#     291     kwarg; otherwise ``JSONDecoder`` is used.
#     292     """
# --> 293     return loads(fp.read(),
#     294         cls=cls, object_hook=object_hook,
#     295         parse_float=parse_float, parse_int=parse_int,
#     296         parse_constant=parse_constant, object_pairs_hook=object_pairs_hook, **kw)
#
# File c:\Users\K3000\anaconda3\envs\sam2\Lib\json\__init__.py:346, in loads(s, cls, object_hook, parse_float, parse_int, parse_constant, object_pairs_hook, **kw)
#     341     s = s.decode(detect_encoding(s), 'surrogatepass')
#     343 if (cls is None and object_hook is None and
#     344         parse_int is None and parse_float is None and
#     345         parse_constant is None and object_pairs_hook is None and not kw):
# --> 346     return _default_decoder.decode(s)
#     347 if cls is None:
#     348     cls = JSONDecoder
#
# File c:\Users\K3000\anaconda3\envs\sam2\Lib\json\decoder.py:337, in JSONDecoder.decode(self, s, _w)
#     332 def decode(self, s, _w=WHITESPACE.match):
#     333     """Return the Python representation of ``s`` (a ``str`` instance
#     334     containing a JSON document).
#     335
#     336     """
# --> 337     obj, end = self.raw_decode(s, idx=_w(s, 0).end())
#     338     end = _w(s, end).end()
#     339     if end != len(s):
#
# File c:\Users\K3000\anaconda3\envs\sam2\Lib\json\decoder.py:353, in JSONDecoder.raw_decode(self, s, idx)
#     344 """Decode a JSON document from ``s`` (a ``str`` beginning with
#     345 a JSON document) and return a 2-tuple of the Python
#     346 representation and the index in ``s`` where the document ended.
#    (...)
#     350
#     351 """
#     352 try:
# --> 353     obj, end = self.scan_once(s, idx)
#     354 except StopIteration as err:
#     355     raise JSONDecodeError("Expecting value", s, err.value) from None
#
# JSONDecodeError: Expecting ',' delimiter: line 8117 column 32 (char 238056)

# %% [markdown]
# ## Loading Data

# %%
data=[] # list of files in dataset
for ff, name in enumerate(os.listdir(os.path.join(formatted_dataset_path, "Images"))):  # go over all folder annotation
    data.append({"image":os.path.join(formatted_dataset_path, "Images", name) , "annotation": os.path.join(formatted_dataset_path, "Masks", name[:-4] + ".png")})

# %% [markdown]
# Show if data is loaded correctly

# %%
data[0]
# Out:
# {'image': 'C:\\Users\\K3000\\Desktop\\conversion test\\new format\\Images\\01850100.MPG_02550.jpg',
#  'annotation': 'C:\\Users\\K3000\\Desktop\\conversion test\\new format\\Masks\\01850100.MPG_02550.png'}

# %% [markdown]
# ## Training

# %%
def read_batch(data): # read random image and its annotation from  the dataset

   #  select image

        ent  = data[np.random.randint(len(data))] # choose random entry
        Img = cv2.imread(ent["image"])[...,::-1]  # read image
        ann_map = cv2.imread(ent["annotation"]) # read annotation
   # resize image

        r = np.min([1024 / Img.shape[1], 1024 / Img.shape[0]]) # scalling factor
        Img = cv2.resize(Img, (int(Img.shape[1] * r), int(Img.shape[0] * r)))
        ann_map = cv2.resize(ann_map, (int(ann_map.shape[1] * r), int(ann_map.shape[0] * r)),interpolation=cv2.INTER_NEAREST)

   # merge vessels and materials annotations

        mat_map = ann_map[:,:,0] # material annotation map
        ves_map = ann_map[:,:,2] # vessel  annotaion map
        mat_map[mat_map==0] = ves_map[mat_map==0]*(mat_map.max()+1) # merged map

   # Get binary masks and points

        inds = np.unique(mat_map)[1:] # load all indices
        points= []
        masks = [] 
        for ind in inds:
            mask=(mat_map == ind).astype(np.uint8) # make binary mask
            masks.append(mask)
            coords = np.argwhere(mask > 0) # get all coordinates in mask
            yx = np.array(coords[np.random.randint(len(coords))]) # choose random point/coordinate
            points.append([[yx[1], yx[0]]])
        return Img,np.array(masks),np.array(points), np.ones([len(masks),1])

# %% [markdown]
# Select, which model shall be trained

# %%
sam2_checkpoint = r"C:\Users\K3000\sam2\checkpoints\sam2.1_hiera_tiny.pt" # path to model weight
model_cfg = r"C:\Users\K3000\sam2\sam2\configs\sam2.1\sam2.1_hiera_t.yaml" # model config
sam2_model = build_sam2(model_cfg, sam2_checkpoint, device="cuda") # load model
predictor = SAM2ImagePredictor(sam2_model) # load net

# %%
predictor.model.sam_mask_decoder.train(True) # enable training of mask decoder 
predictor.model.sam_prompt_encoder.train(True) # enable training of prompt encoder
# Out:
# PromptEncoder(
#   (pe_layer): PositionEmbeddingRandom()
#   (point_embeddings): ModuleList(
#     (0-3): 4 x Embedding(1, 256)
#   )
#   (not_a_point_embed): Embedding(1, 256)
#   (mask_downscaling): Sequential(
#     (0): Conv2d(1, 4, kernel_size=(2, 2), stride=(2, 2))
#     (1): LayerNorm2d()
#     (2): GELU(approximate='none')
#     (3): Conv2d(4, 16, kernel_size=(2, 2), stride=(2, 2))
#     (4): LayerNorm2d()
#     (5): GELU(approximate='none')
#     (6): Conv2d(16, 256, kernel_size=(1, 1), stride=(1, 1))
#   )
#   (no_mask_embed): Embedding(1, 256)
# )

# %%
optimizer=torch.optim.AdamW(params=predictor.model.parameters(),lr=1e-5,weight_decay=4e-5)

# %%
scaler = torch.cuda.amp.GradScaler() # set mixed precision

# %%
for itr in range(100000):
    with torch.cuda.amp.autocast(): # cast to mix precision
        #with torch.cuda.amp.autocast():
            image,mask,input_point, input_label = read_batch(data) # load data batch
            if mask.shape[0]==0: continue # ignore empty batches
            predictor.set_image(image) # apply SAM image encodet to the image

            # prompt encoding

            mask_input, unnorm_coords, labels, unnorm_box = predictor._prep_prompts(input_point, input_label, box=None, mask_logits=None, normalize_coords=True)
            sparse_embeddings, dense_embeddings = predictor.model.sam_prompt_encoder(points=(unnorm_coords, labels),boxes=None,masks=None,)

            # mask decoder

            batched_mode = unnorm_coords.shape[0] > 1 # multi object prediction
            high_res_features = [feat_level[-1].unsqueeze(0) for feat_level in predictor._features["high_res_feats"]]
            low_res_masks, prd_scores, _, _ = predictor.model.sam_mask_decoder(image_embeddings=predictor._features["image_embed"][-1].unsqueeze(0),image_pe=predictor.model.sam_prompt_encoder.get_dense_pe(),sparse_prompt_embeddings=sparse_embeddings,dense_prompt_embeddings=dense_embeddings,multimask_output=True,repeat_image=batched_mode,high_res_features=high_res_features,)
            prd_masks = predictor._transforms.postprocess_masks(low_res_masks, predictor._orig_hw[-1])# Upscale the masks to the original image resolution

            # Segmentaion Loss caclulation

            gt_mask = torch.tensor(mask.astype(np.float32)).cuda()
            prd_mask = torch.sigmoid(prd_masks[:, 0])
            seg_loss = (-gt_mask * torch.log(prd_mask + 0.00001) - (1 - gt_mask) * torch.log((1 - prd_mask) + 0.00001)).mean()

            # Score loss calculation (intersection over union) IOU

            inter = (gt_mask * (prd_mask > 0.5)).sum(1).sum(1)
            iou = inter / (gt_mask.sum(1).sum(1) + (prd_mask > 0.5).sum(1).sum(1) - inter)
            score_loss = torch.abs(prd_scores[:, 0] - iou).mean()
            loss=seg_loss+score_loss*0.05  # mix losses

            # apply back propogation

            predictor.model.zero_grad() # empty gradient
            scaler.scale(loss).backward()  # Backpropogate
            scaler.step(optimizer)
            scaler.update() # Mix precision

            if itr%1000==0: torch.save(predictor.model.state_dict(), "model.torch") # save model

            # Display results

            if itr==0: 
                mean_iou=0
                
            mean_iou = mean_iou * 0.99 + 0.01 * np.mean(iou.cpu().detach().numpy())
            
            print("step", itr, "Accuracy(IOU)=",mean_iou)
